# %%
# %load_ext autoreload
# %autoreload 2

# %%
from DCGAN.dcgan import dcgan_pass

# %%
pass1=dcgan_pass()
gen,disc=pass1.train(train_path='pretrain_data', num_epochs=20)
# Out:
# Epoch [0/20] Batch 0/8 \Loss D: 0.6939, loss G: 0.7984
# Epoch [1/20] Batch 0/8 \Loss D: 0.4214, loss G: 1.1228
# Epoch [2/20] Batch 0/8 \Loss D: 0.3256, loss G: 1.3214
# Epoch [3/20] Batch 0/8 \Loss D: 0.2621, loss G: 1.5001
# Epoch [4/20] Batch 0/8 \Loss D: 0.2124, loss G: 1.6839
# Epoch [5/20] Batch 0/8 \Loss D: 0.1715, loss G: 1.8762
# Epoch [6/20] Batch 0/8 \Loss D: 0.1399, loss G: 2.0644
# Epoch [7/20] Batch 0/8 \Loss D: 0.1130, loss G: 2.2610
# Epoch [8/20] Batch 0/8 \Loss D: 0.0921, loss G: 2.4505
# Epoch [9/20] Batch 0/8 \Loss D: 0.0763, loss G: 2.6323
# Epoch [10/20] Batch 0/8 \Loss D: 0.0634, loss G: 2.8065
# Epoch [11/20] Batch 0/8 \Loss D: 0.0596, loss G: 2.9704
# Epoch [12/20] Batch 0/8 \Loss D: 0.0456, loss G: 3.1275
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22448/386324011.py in <module>
#       1 pass1=dcgan_pass()
# ...
